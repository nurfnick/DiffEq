# %% [markdown]
# <a href="https://colab.research.google.com/github/nurfnick/DiffEq/blob/main/flowOnSystems.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

a = np.array([[4,-5],[5,-2]])

t13 = np.arange(-3,3,1)
t2 = np.arange(-3,3,1)
t13,t2 = np.meshgrid(t13,t2)

x = a[0,0]*t13 + a[0,1]*t2
y = a[1,0]*t13 + a[1,1]*t2

t1 = np.arange(0,2,0.01)
c1,c2 = 0,1
sol1, sol2 = np.e**t1*(c1*5*np.cos(4*t1)+c2*5*np.sin(4*t1)), c1*np.e**t1*(3*np.cos(4*t1)-4*np.sin(4*t1))+c2*np.e**t1*(4*np.cos(4*t1)+3*np.sin(4*t1))
plt.quiver(x,y,t13,t2,scale = .1)
plt.plot(sol1,sol2)
#plt.plot(sol1,sol2)
plt.show()
